# %% [markdown]
# # Nakazato 2013 models

# %%
from sspike import pnut, beer
from sspike.snowball import Snowball
from sspike.targets import Target

# %%
model = 'Nakazato_2013'
progenitor = {'mass': 20,
              'metal': 0.02,
              't_rev': 300}
transformation = 'NoTransformation'
distance = 5

# %%
sb = Snowball(model, progenitor, transformation, distance)
target = Target('kamland')
snowflakes = pnut.snowglobes_events(sb, target)
sspikes = pnut.sspike_events(sb, target)
# Out:
# /Users/joe/opt/anaconda3/envs/KLSN/lib/python3.8/site-packages/astropy/table/row.py:76: FutureWarning: elementwise == comparison failed and returning scalar instead; this will raise an error or perform elementwise comparison in the future.
#   return self.as_void() == other
# /Users/joe/opt/anaconda3/envs/KLSN/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2944: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return runner(coro)

# %%
nc_chans = target.nc_channels
beer.draw(sspikes[-1], channels=nc_chans)

# %%
smear_path = '/Users/joe/src/gitjoe/sspike/snowballs/Nak-20-20-300/5kpc-NoTransformation/snow-unsmeared.csv'
snow_chans = target.snow_channels
beer.draw(smear_path, channels=snow_chans)

# %%
basic_chans = target.basic_channels
beer.draw(sspikes[0], channels=basic_chans)

# %%
tab = beer.tab(sb)

# %%
unsmeared_path = snowflakes[0]
snow_chans = target.snow_channels[:7]
beer.draw(unsmeared_path, channels=snow_chans)
