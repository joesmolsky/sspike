# %% [markdown]
# # Tamborra 2014
#
# ## Abstract
#
# *The neutrino emission characteristics of the first full-scale three-dimensional supernova simulations with sophisticated three-flavor neutrino transport for three models with masses 11.2, 20 and 27 M_sun are evaluated in detail. All the studied progenitors show the expected hydrodynamical instabilities in the form of large-scale convective overturn. In addition, the recently identified LESA phenomenon (lepton-number emission self-sustained asymmetry) is generic for all our cases. Pronounced SASI (standing accretion-shock instability) activity appears in the 20 and 27 M_sun cases, partly in the form of a spiral mode, inducing large but direction and flavor-dependent modulations of neutrino emission. These modulations can be clearly identified in the existing IceCube and future Hyper-Kamiokande detectors, depending on distance and detector location relative to the main SASI sloshing direction.*
#
# ### snewpy readme
#
# Data from I. Tamborra, G. Raffelt, F. Hanke, H.-T. Janka, and B. Mueller *Neutrino emission characteristics and detection opportunities based on three-dimensional supernova simulations*, [Phys. Rev. D 90:045032, 2014](https://arxiv.org/abs/1406.0006).
#
# Files taken from the [Garching Supernova archive](http://wwwmpa.mpa-garching.mpg.de/ccsnarchive/data/Tamborra2014/) for 20Msun and 27Msun, with permission to include them into snewpy.
#
# NOTE: same file format as for Bollig_2016 models.

# %%
from sspike import pnut, beer
from sspike.supernova import Supernova
from sspike.detectors import Detector

# %% [markdown]
# ## Progenitor options
#
# - `mass`: 20.0 or 27.0 S.M.
# - `t_start`: 0.0065017 or 0.0105
# - `t_end`: 0.33801 or 0.55162

# %%
model = 'Tamborra_2014'
progenitor = {'mass': 20.0}
transformation = 'NoTransformation'
distance = 10.0

# %%
detector = Detector('kamland')
sn = Supernova(model, progenitor, transformation, distance)

# %%
# lum = pnut.get_luminosities(sn)
beer.plot_luminosities(sn)

# %%
# fluences = pnut.get_fluences(sn)
beer.plot_fluences(sn)

# %%
snow_events = pnut.snowglobes_events(sn, detector)
beer.plot_snowglobes_events(sn, detector)

# %%
sspike_events = pnut.sspike_events(sn, detector)
beer.plot_sspike_events(sn, detector)

# %%
# totals = pnut.event_totals(sn, detector)
beer.bar_totals(sn, detector)

# %%
vis = pnut.vis_totals(sn, detector)
beer.bar_vis(sn, detector)

# %%
vis
# Out:
#            model  mass     channel     events
# 0  Tamborra_2014  20.0         ibd  74.223063
# 1  Tamborra_2014  20.0     nue_C12   1.161222
# 2  Tamborra_2014  20.0     nue_C13   0.142917
# 3  Tamborra_2014  20.0  nuebar_C12   2.106963
# 4  Tamborra_2014  20.0          nc   6.245389
# 5  Tamborra_2014  20.0           e   4.751546
# 6  Tamborra_2014  20.0        nc_p   0.443927

# %%
beer.plot_distance_rates(sn, detector)

# %% [markdown]
# ## Time series

# %%
t_bins = 199
sn2 = Supernova(model, progenitor, transformation, distance, t_bins)

# %%
counts = pnut.time_events(sn2, detector)
beer.plot_series(sn2, detector)

# %%
beer.plot_N_chan(sn2, detector, 'ibd')

# %%
beer.plot_N_chan(sn2, detector, 'ibd', events=True, save=False)

# %%
vis
# Out:
#            model  mass     channel     events
# 0  Tamborra_2014  20.0         ibd  74.223063
# 1  Tamborra_2014  20.0     nue_C12   1.161222
# 2  Tamborra_2014  20.0     nue_C13   0.142917
# 3  Tamborra_2014  20.0  nuebar_C12   2.106963
# 4  Tamborra_2014  20.0          nc   6.245389
# 5  Tamborra_2014  20.0           e   4.751546
# 6  Tamborra_2014  20.0        nc_p   0.443927
