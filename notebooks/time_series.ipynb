# %% [markdown]
# # Time series
#
# Run a single model times series and generate random events.

# %%
from sspike import pnut, beer
from sspike.supernova import Supernova
from sspike.detectors import Detector

# %% [markdown]
# ## Detector
#
# Choose any detector in SNOwGLoBES and snewpy.

# %%
detector = Detector('kamland')

# %% [markdown]
# ## Supernova

# %%
model = 'Nakazato_2013'
progenitor = {'mass': 20, 't_rev': 300, 'metal': 0.02}
xforms = ['NoTransformation', 'AdiabaticMSW_NMO', "AdiabaticMSW_IMO"]
transformation = xforms[0]
distance = 10.0
t_bins = 20
t_start = 0.0065017
t_end = 0.33801
sn = Supernova(model, progenitor, transformation, distance, t_bins, t_start, t_end)

# %% [markdown]
# ## Event rates by channel

# %%
counts = pnut.time_events(sn, detector)
beer.plot_series(sn, detector)
# Out:
# /Users/joe/opt/anaconda3/envs/KLSN/lib/python3.8/site-packages/astropy/table/row.py:76: FutureWarning: elementwise == comparison failed and returning scalar instead; this will raise an error or perform elementwise comparison in the future.
#   return self.as_void() == other

# %% [markdown]
# ## Single channel rates

# %%
chan = 'ibd'
beer.plot_N_chan(sn, detector, chan)

# %%
chan = 'ibd'
beer.plot_N_chan(sn, detector, chan, events=True)
