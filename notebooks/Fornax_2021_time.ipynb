# %% [markdown]
# # Supernova event rates vs. time

# %%
from sspike import pnut, beer
from sspike.snowball import Snowball
from sspike.detectors import Detector

# %%
model = 'Fornax_2021'
progenitor = {'mass': 20}
transformation = 'NoTransformation'
distance = 1.5
t_bins = 10

# %%
bliz = Snowball(model, progenitor, transformation, distance, t_bins)
detector = Detector('kamland')
sno = pnut.time_events(bliz.tarball, detector.name)
# Out:
# /Users/joe/opt/anaconda3/envs/KLSN/lib/python3.8/site-packages/astropy/table/row.py:76: FutureWarning: elementwise == comparison failed and returning scalar instead; this will raise an error or perform elementwise comparison in the future.
#   return self.as_void() == other
# ╭──────────────────────────── Traceback (most recent call last) ────────────────────────────╮
# │                                                                                           │
# │ /var/folders/bs/t_j9r03n3h39lmjyz9hr6b540000gn/T/ipykernel_43344/4012283007.py:3 in       │
# │ <module>                                                                                  │
# │                                                                                           │
# │ [Errno 2] No such file or directory:                                                      │
# │ '/var/folders/bs/t_j9r03n3h39lmjyz9hr6b540000gn/T/ipykernel_43344/4012283007.py'          │
# │ /Users/joe/src/gitjoe/sspike/sspike/pnut.py:350 in time_events                            │
# │                                                                                           │
# │   347 │   """Process time series with snowglobes."""                                      │
# │   348 │                                                                                   │
# │   349 │   snowglobes.simulate(snowglobes_dir, bliz, detector_input=detector)              │
# │ ❱ 350 │   tables = snowglobes.collate(snowglobes_dir, bliz, skip_plots=True)              │
# │   351 │                                                                                   │
# │   352 │   return tables                                                                   │
# │   353                                                                                     │
# │                                                                                           │
# │ /Users/joe/src/snewpy/python/snewpy/snowglobes.py:478 in collate                          │
# │                                                                                           │
# │   475 │   │   │   │   │   │   filename = tempdir/f'Collated_{filename_base}.dat'          │
# │   476 │   │   │   │   │   │   #save results to text files                                 │
# │   477 │   │   │   │   │   │   with open(filename,'w') as f:                               │
# │ ❱ 478 │   │   │   │   │   │   │   f.write(table.to_string(float_format='%23.15g'))        │
# │   479 │   │   │   │   │   │   #format the results for the output                          │
# │   480 │   │   │   │   │   │   header = 'Energy '+' '.join(list(table.columns))            │
# │   481 │   │   │   │   │   │   data = table.to_numpy().T                                   │
# │                                                                                           │
# │ /Users/joe/opt/anaconda3/envs/KLSN/lib/python3.8/site-packages/pandas/core/frame.py:1131  │
# │ in to_string                                                                              │
# │                                                                                           │
# │    1128 │   │   │   │   show_dimensions=show_dimensions,                                  │
# │    1129 │   │   │   │   decimal=decimal,                                                  │
# │    1130 │   │   │   )                                                                     │
# │ ❱  1131 │   │   │   return fmt.DataFrameRenderer(formatter).to_string(                    │
# │    1132 │   │   │   │   buf=buf,                                                          │
# │    1133 │   │   │   │   encoding=encoding,                                                │
# │    1134 │   │   │   │   line_width=line_width,                                            │
# │                                                                                           │
# │ /Users/joe/opt/anaconda3/envs/KLSN/lib/python3.8/site-packages/pandas/io/formats/format.p │
# │ y:1053 in to_string                                                                       │
# │                                                                                           │
# │   1050 │   │   from pandas.io.formats.string import StringFormatter                       │
# │   1051 │   │                                                                              │
# │   1052 │   │   string_formatter = StringFormatter(self.fmt, line_width=line_width)        │
# │ ❱ 1053 │   │   string = string_formatter.to_string()                                      │
# │   1054 │   │   return save_to_buffer(string, buf=buf, encoding=encoding)                  │
# │   1055 │                                                                                  │
# │   1056 │   def to_csv(                                                                    │
# │                                                                                           │
# │ /Users/joe/opt/anaconda3/envs/KLSN/lib/python3.8/site-packages/pandas/io/formats/string.p │
# │ y:25 in to_string                                                                         │
# │                                                                                           │
# │    22 │   │   self.line_width = line_width                                                │
# │    23 │                                                                                   │
# │    24 │   def to_string(self) -> str:                                                     │
# │ ❱  25 │   │   text = self._get_string_representation()                                    │
# │    26 │   │   if self.fmt.should_show_dimensions:                                         │
# │    27 │   │   │   text = "".join([text, self.fmt.dimensions_info])                        │
# │    28 │   │   return text                                                                 │
# │                                                                                           │
# │ /Users/joe/opt/anaconda3/envs/KLSN/lib/python3.8/site-packages/pandas/io/formats/string.p │
# │ y:40 in _get_string_representation                                                        │
# │                                                                                           │
# │    37 │   │   if self.fmt.frame.empty:                                                    │
# │    38 │   │   │   return self._empty_info_line                                            │
# │    39 │   │                                                                               │
# │ ❱  40 │   │   strcols = self._get_strcols()                                               │
# │    41 │   │                                                                               │
# │    42 │   │   if self.line_width is None:                                                 │
# │    43 │   │   │   # no need to wrap around just print the whole frame                     │
# │                                                                                           │
# │ /Users/joe/opt/anaconda3/envs/KLSN/lib/python3.8/site-packages/pandas/io/formats/string.p │
# │ y:31 in _get_strcols                                                                      │
# │                                                                                           │
# │    28 │   │   return text                                                                 │
# │    29 │                                                                                   │
# │    30 │   def _get_strcols(self) -> list[list[str]]:                                      │
# │ ❱  31 │   │   strcols = self.fmt.get_strcols()                                            │
# │    32 │   │   if self.fmt.is_truncated:                                                   │
# │    33 │   │   │   strcols = self._insert_dot_separators(strcols)                          │
# │    34 │   │   return strcols                                                              │
# │                                                                                           │
# │ /Users/joe/opt/anaconda3/envs/KLSN/lib/python3.8/site-packages/pandas/io/formats/format.p │
# │ y:540 in get_strcols                                                                      │
# │                                                                                           │
# │    537 │   │   """                                                                        │
# │    538 │   │   Render a DataFrame to a list of columns (as lists of strings).             │
# │    539 │   │   """                                                                        │
# │ ❱  540 │   │   strcols = self._get_strcols_without_index()                                │
# │    541 │   │                                                                              │
# │    542 │   │   if self.index:                                                             │
# │    543 │   │   │   str_index = self._get_formatted_index(self.tr_frame)                   │
# │                                                                                           │
# │ /Users/joe/opt/anaconda3/envs/KLSN/lib/python3.8/site-packages/pandas/io/formats/format.p │
# │ y:804 in _get_strcols_without_index                                                       │
# │                                                                                           │
# │    801 │   │   │   header_colwidth = max(                                                 │
# │    802 │   │   │   │   int(self.col_space.get(c, 0)), *(self.adj.len(x) for x in cheader) │
# │    803 │   │   │   )                                                                      │
# │ ❱  804 │   │   │   fmt_values = self.format_col(i)                                        │
# │    805 │   │   │   fmt_values = _make_fixed_width(                                        │
# │    806 │   │   │   │   fmt_values, self.justify, minimum=header_colwidth, adj=self.adj    │
# │    807 │   │   │   )                                                                      │
# │                                                                                           │
# │ /Users/joe/opt/anaconda3/envs/KLSN/lib/python3.8/site-packages/pandas/io/formats/format.p │
# │ y:818 in format_col                                                                       │
# │                                                                                           │
# │    815 │   def format_col(self, i: int) -> list[str]:                                     │
# │    816 │   │   frame = self.tr_frame                                                      │
# │    817 │   │   formatter = self._get_formatter(i)                                         │
# │ ❱  818 │   │   return format_array(                                                       │
# │    819 │   │   │   frame.iloc[:, i]._values,                                              │
# │    820 │   │   │   formatter,                                                             │
# │    821 │   │   │   float_format=self.float_format,                                        │
# │                                                                                           │
# │ /Users/joe/opt/anaconda3/envs/KLSN/lib/python3.8/site-packages/pandas/io/formats/format.p │
# │ y:1240 in format_array                                                                    │
# │                                                                                           │
# │   1237 │   │   quoting=quoting,                                                           │
# │   1238 │   )                                                                              │
# │   1239 │                                                                                  │
# │ ❱ 1240 │   return fmt_obj.get_result()                                                    │
# │   1241                                                                                    │
# │   1242                                                                                    │
# │   1243 class GenericArrayFormatter:                                                       │
# │                                                                                           │
# │ /Users/joe/opt/anaconda3/envs/KLSN/lib/python3.8/site-packages/pandas/io/formats/format.p │
# │ y:1271 in get_result                                                                      │
# │                                                                                           │
# │   1268 │   │   self.leading_space = leading_space                                         │
# │   1269 │                                                                                  │
# │   1270 │   def get_result(self) -> list[str]:                                             │
# │ ❱ 1271 │   │   fmt_values = self._format_strings()                                        │
# │   1272 │   │   return _make_fixed_width(fmt_values, self.justify)                         │
# │   1273 │                                                                                  │
# │   1274 │   def _format_strings(self) -> list[str]:                                        │
# │                                                                                           │
# │ /Users/joe/opt/anaconda3/envs/KLSN/lib/python3.8/site-packages/pandas/io/formats/format.p │
# │ y:1518 in _format_strings                                                                 │
# │                                                                                           │
# │   1515 │   │   return formatted_values                                                    │
# │   1516 │                                                                                  │
# │   1517 │   def _format_strings(self) -> list[str]:                                        │
# │ ❱ 1518 │   │   return list(self.get_result_as_array())                                    │
# │   1519                                                                                    │
# │   1520                                                                                    │
# │   1521 class IntArrayFormatter(GenericArrayFormatter):                                    │
# │                                                                                           │
# │ /Users/joe/opt/anaconda3/envs/KLSN/lib/python3.8/site-packages/pandas/io/formats/format.p │
# │ y:1482 in get_result_as_array                                                             │
# │                                                                                           │
# │   1479 │   │   else:                                                                      │
# │   1480 │   │   │   float_format = lambda value: self.float_format % value                 │
# │   1481 │   │                                                                              │
# │ ❱ 1482 │   │   formatted_values = format_values_with(float_format)                        │
# │   1483 │   │                                                                              │
# │   1484 │   │   if not self.fixed_width:                                                   │
# │   1485 │   │   │   return formatted_values                                                │
# │                                                                                           │
# │ /Users/joe/opt/anaconda3/envs/KLSN/lib/python3.8/site-packages/pandas/io/formats/format.p │
# │ y:1456 in format_values_with                                                              │
# │                                                                                           │
# │   1453 │   │   │   # separate the wheat from the chaff                                    │
# │   1454 │   │   │   values = self.values                                                   │
# │   1455 │   │   │   is_complex = is_complex_dtype(values)                                  │
# │ ❱ 1456 │   │   │   values = format_with_na_rep(values, formatter, na_rep)                 │
# │   1457 │   │   │                                                                          │
# │   1458 │   │   │   if self.fixed_width:                                                   │
# │   1459 │   │   │   │   if is_complex:                                                     │
# │                                                                                           │
# │ /Users/joe/opt/anaconda3/envs/KLSN/lib/python3.8/site-packages/pandas/io/formats/format.p │
# │ y:1427 in format_with_na_rep                                                              │
# │                                                                                           │
# │   1424 │   │   def format_with_na_rep(values: ArrayLike, formatter: Callable, na_rep: str │
# │   1425 │   │   │   mask = isna(values)                                                    │
# │   1426 │   │   │   formatted = np.array(                                                  │
# │ ❱ 1427 │   │   │   │   [                                                                  │
# │   1428 │   │   │   │   │   formatter(val) if not m else na_rep                            │
# │   1429 │   │   │   │   │   for val, m in zip(values.ravel(), mask.ravel())                │
# │   1430 │   │   │   │   ]                                                                  │
# │                                                                                           │
# │ /Users/joe/opt/anaconda3/envs/KLSN/lib/python3.8/site-packages/pandas/io/formats/format.p │
# │ y:1428 in <listcomp>                                                                      │
# │                                                                                           │
# │   1425 │   │   │   mask = isna(values)                                                    │
# │   1426 │   │   │   formatted = np.array(                                                  │
# │   1427 │   │   │   │   [                                                                  │
# │ ❱ 1428 │   │   │   │   │   formatter(val) if not m else na_rep                            │
# │   1429 │   │   │   │   │   for val, m in zip(values.ravel(), mask.ravel())                │
# │   1430 │   │   │   │   ]                                                                  │
# │   1431 │   │   │   ).reshape(values.shape)                                                │
# │                                                                                           │
# │ /Users/joe/opt/anaconda3/envs/KLSN/lib/python3.8/site-packages/pandas/io/formats/format.p │
# │ y:1387 in base_formatter                                                                  │
# │                                                                                           │
# │   1384 │   │   │   │   # "EngFormatter"                                                   │
# │   1385 │   │   │   │   return (                                                           │
# │   1386 │   │   │   │   │   float_format(value=v)  # type: ignore[operator,call-arg]       │
# │ ❱ 1387 │   │   │   │   │   if notna(v)                                                    │
# │   1388 │   │   │   │   │   else self.na_rep                                               │
# │   1389 │   │   │   │   )                                                                  │
# │   1390                                                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt

# %%
times = beer.bin_times(bliz)
plot_type = '_unsmeared_weighted'
beer.series_plot(bliz, sno, times, plot_type)
