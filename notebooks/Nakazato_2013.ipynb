# %% [markdown]
# # Nakazato 2013 models

# %%
from sspike import pnut, beer
from sspike.supernova import Supernova
from sspike.detectors import Detector

# %%
model = 'Nakazato_2013'
progenitor = {'mass': 20,
              'metal': 0.02,
              't_rev': 300}
transformation = 'NoTransformation'
distance = 10.0

# %%
detector = Detector('kamland')
sn = Supernova(model, progenitor, transformation, distance)

# %%
lum = pnut.get_luminosities(sn)
beer.plot_luminosities(sn, lum)

# %%
fluences = pnut.get_fluences(sn)
beer.plot_fluences(sn)

# %%
snow_events = pnut.snowglobes_events(sn, detector)
beer.plot_snowglobes_events(sn, detector)

# %%
sspike_events = pnut.sspike_events(sn, detector)
beer.plot_sspike_events(sn, detector)

# %%
totals = pnut.event_totals(sn, detector)
beer.bar_totals(sn, detector)

# %%
vis = pnut.vis_totals(sn, detector)
beer.bar_vis(sn, detector)

# %%
t_bins = 10
t_start = 0.0
t_end = 0.5
sn2 = Supernova(model, progenitor, transformation, distance, t_bins, t_start, t_end)

# %%
counts = pnut.time_events(sn2, detector)
beer.plot_series(sn2, detector)

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt

# %%
beer.plot_N_chan(sn2, detector, 'ibd')
# energy = list(counts['ibd'].keys())
# times = counts['ibd'].index
# t0, t1 = times[0], times[-1]
# e0, e1 = energy[1]*1e3, energy[-1]*1e3

# plt.imshow(counts['ibd'].iloc[:,1:], origin='lower', extent=[e0, e1, t0, t1], aspect='auto', interpolation='none')

# plt.xlabel('Energy [MeV]')
# plt.ylabel('Time [s]')
# plt.colorbar(label='counts')

# %%
beer.plot_N_chan(sn2, detector, "random", save=False)
# rand = pd.DataFrame(np.random.random(size=np.shape(data)), columns=list(data.keys()))

# plt.imshow(rand, origin='lower', extent=[e0, e1, t0, t1], aspect='auto', interpolation='none')
# plt.xlabel('Energy [MeV]')
# plt.ylabel('Time [s]')
# plt.colorbar(label='counts')

# %%
dfs = beer.plot_N_chan(sn2, detector, 'ibd', events=True, save=False)
# rand = pd.DataFrame(np.random.random(size=np.shape(data)), columns=list(data.keys()))
# df = np.where(data > rand, 1, 0)
# plt.imshow(df, origin='lower', extent=[e0, e1, t0, t1], aspect='auto', interpolation='none')

# plt.xlabel('Energy [MeV]')
# plt.ylabel('Time [s]')
# plt.colorbar(label='Events')
# print(np.sum(df))
# Out:
# ╭──────────────────────────── Traceback (most recent call last) ────────────────────────────╮
# │                                                                                           │
# │ /var/folders/bs/t_j9r03n3h39lmjyz9hr6b540000gn/T/ipykernel_20777/3203651146.py:1 in       │
# │ <module>                                                                                  │
# │                                                                                           │
# │ [Errno 2] No such file or directory:                                                      │
# │ '/var/folders/bs/t_j9r03n3h39lmjyz9hr6b540000gn/T/ipykernel_20777/3203651146.py'          │
# │ /Users/joe/src/gitjoe/sspike/sspike/beer.py:363 in plot_N_chan                            │
# │                                                                                           │
# │   360 │   e0, e1 = energy[0] * 1e3, energy[-1] * 1e3                                      │
# │   361 │                                                                                   │
# │   362 │   if events:                                                                      │
# │ ❱ 363 │   │   N_chan = np.where(N_chan > sn.random_df(), 1, 0)                            │
# │   364 │                                                                                   │
# │   365 │   plt.imshow(                                                                     │
# │   366 │   │   N_chan,                                                                     │
# │                                                                                           │
# │ /Users/joe/opt/anaconda3/envs/KLSN/lib/python3.8/site-packages/pandas/core/ops/common.py: │
# │ 69 in new_method                                                                          │
# │                                                                                           │
# │    66 │   │                                                                               │
# │    67 │   │   other = item_from_zerodim(other)                                            │
# │    68 │   │                                                                               │
# │ ❱  69 │   │   return method(self, other)                                                  │
# │    70 │                                                                                   │
# │    71 │   return new_method                                                               │
# │    72                                                                                     │
# │                                                                                           │
# │ /Users/joe/opt/anaconda3/envs/KLSN/lib/python3.8/site-packages/pandas/core/arraylike.py:4 │
# │ 8 in __gt__                                                                               │
# │                                                                                           │
# │    45 │                                                                                   │
# │    46 │   @unpack_zerodim_and_defer("__gt__")                                             │
# │    47 │   def __gt__(self, other):                                                        │
# │ ❱  48 │   │   return self._cmp_method(other, operator.gt)                                 │
# │    49 │                                                                                   │
# │    50 │   @unpack_zerodim_and_defer("__ge__")                                             │
# │    51 │   def __ge__(self, other):                                                        │
# │                                                                                           │
# │ /Users/joe/opt/anaconda3/envs/KLSN/lib/python3.8/site-packages/pandas/core/frame.py:6851  │
# │ in _cmp_method                                                                            │
# │                                                                                           │
# │    6848 │   def _cmp_method(self, other, op):                                             │
# │    6849 │   │   axis = 1  # only relevant for Series other case                           │
# │    6850 │   │                                                                             │
# │ ❱  6851 │   │   self, other = ops.align_method_FRAME(self, other, axis, flex=False, level │
# │    6852 │   │                                                                             │
# │    6853 │   │   # See GH#4537 for discussion of scalar op behavior                        │
# │    6854 │   │   new_data = self._dispatch_frame_op(other, op, axis=axis)                  │
# │                                                                                           │
# │ /Users/joe/opt/anaconda3/envs/KLSN/lib/python3.8/site-packages/pandas/core/ops/__init__.p │
# │ y:288 in align_method_FRAME                                                               │
# │                                                                                           │
# │   285 │   │   │   if flex:                                                                │
# │   286 │   │   │   │   left, right = left.align(right, join="outer", level=level, copy=Fal │
# │   287 │   │   │   else:                                                                   │
# │ ❱ 288 │   │   │   │   raise ValueError(                                                   │
# │   289 │   │   │   │   │   "Can only compare identically-labeled DataFrame objects"        │
# │   290 │   │   │   │   )                                                                   │
# │   291 │   elif isinstance(right, ABCSeries):                                              │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯
# ValueError: Can only compare identically-labeled DataFrame objects
